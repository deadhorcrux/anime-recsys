# %%
import pandas as pd

# %%
df = pd.read_pickle('../data/recs.pickle')

# %%
df[df['user_name'] == 'morr']
# Out:
#    user_id item_id  rank                                    title user_name
# 0        1    1535     1                           Тетрадь смерти      morr
# 0        1    1575     2               Код Гиас: Восставший Лелуш      morr
# 0        1     226     3                         Эльфийская песнь      morr
# 0        1     245     4                  Крутой учитель Онидзука      morr
# 0        1      71     5                        Стальная тревога!      morr
# 0        1    1210     6                   Добро пожаловать в NHK      morr
# 0        1     121     7                         Стальной алхимик      morr
# 0        1    1195     8                   Подручный Луизы-Нулизы      morr
# 0        1    1840     9  Подручный Луизы-Нулизы: Рыцарь двух лун      morr
# 0        1    5081    10                         Истории монстров      morr
